# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("/home/digimantra/Downloads/exams.csv")
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
data['gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data['race/ethnicity'].unique()
# Out:
# array(['group A', 'group D', 'group E', 'group B', 'group C'],
#       dtype=object)

# %%
data.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     77
# reading score                  73
# writing score                  76
# dtype: int64

# %%
#checking for null value
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#droping the unnnecessary data
data1=data.drop(["race/ethnicity"],axis=1)
data1.head()
# Out:
#    gender parental level of education         lunch test preparation course  \
# 0    male                 high school      standard               completed
# 1  female            some high school  free/reduced                    none
# 2    male                some college  free/reduced                    none
# 3    male                 high school      standard                    none
# 4    male          associate's degree      standard               completed
#
#    math score  reading score  writing score
# 0          67             67             63
# 1          40             59             55
# 2          59             60             50
# 3          77             78             68
# 4          78             73             68

# %%
correlation = data1.corr()

# %%
sns.pairplot(data1)

# %%
#you can perform it with different different charts

# %% [markdown]
# #now we took more messy data

# %%
new = pd.read_csv("/home/digimantra/Downloads/owid-covid-data.csv")
new
# Out:
#        iso_code continent     location        date  population  total_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24  41128772.0          5.0
# 1           AFG      Asia  Afghanistan  2020-02-25  41128772.0          5.0
# 2           AFG      Asia  Afghanistan  2020-02-26  41128772.0          5.0
# 3           AFG      Asia  Afghanistan  2020-02-27  41128772.0          5.0
# 4           AFG      Asia  Afghanistan  2020-02-28  41128772.0          5.0
# ...         ...       ...          ...         ...         ...          ...
# 237206      ZWE    Africa     Zimbabwe  2022-11-19  16320539.0     257893.0
# 237207      ZWE    Africa     Zimbabwe  2022-11-20  16320539.0     257893.0
# 237208      ZWE    Africa     Zimbabwe  2022-11-21  16320539.0     257893.0
# 237209      ZWE    Africa     Zimbabwe  2022-11-22  16320539.0     257893.0
# 237210      ZWE    Africa     Zimbabwe  2022-11-23  16320539.0     257893.0
#
# ...

# %%
new.head()
# Out:
#   iso_code continent     location        date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24  41128772.0          5.0
# 1      AFG      Asia  Afghanistan  2020-02-25  41128772.0          5.0
# 2      AFG      Asia  Afghanistan  2020-02-26  41128772.0          5.0
# 3      AFG      Asia  Afghanistan  2020-02-27  41128772.0          5.0
# 4      AFG      Asia  Afghanistan  2020-02-28  41128772.0          5.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  male_smokers  \
# 0        5.0                 NaN           NaN         NaN  ...           NaN
# 1        0.0                 NaN           NaN         NaN  ...           NaN
# 2        0.0                 NaN           NaN         NaN  ...           NaN
# 3        0.0                 NaN           NaN         NaN  ...           NaN
# 4        0.0                 NaN           NaN         NaN  ...           NaN
#
# ...

# %%
new.tail()
# Out:
#        iso_code continent  location        date  population  total_cases  \
# 237206      ZWE    Africa  Zimbabwe  2022-11-19  16320539.0     257893.0
# 237207      ZWE    Africa  Zimbabwe  2022-11-20  16320539.0     257893.0
# 237208      ZWE    Africa  Zimbabwe  2022-11-21  16320539.0     257893.0
# 237209      ZWE    Africa  Zimbabwe  2022-11-22  16320539.0     257893.0
# 237210      ZWE    Africa  Zimbabwe  2022-11-23  16320539.0     257893.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 237206        0.0                 0.0        5606.0         0.0  ...
# 237207        0.0                 0.0        5606.0         0.0  ...
# 237208        0.0                 0.0        5606.0         0.0  ...
# 237209        0.0                 0.0        5606.0         0.0  ...
# 237210        0.0                 0.0        5606.0         0.0  ...
#
#         male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
new1= new[['continent','population','total_cases']]

# %%
new1
# Out:
#        continent  population  total_cases
# 0           Asia  41128772.0          5.0
# 1           Asia  41128772.0          5.0
# 2           Asia  41128772.0          5.0
# 3           Asia  41128772.0          5.0
# 4           Asia  41128772.0          5.0
# ...          ...         ...          ...
# 237206    Africa  16320539.0     257893.0
# 237207    Africa  16320539.0     257893.0
# 237208    Africa  16320539.0     257893.0
# 237209    Africa  16320539.0     257893.0
# 237210    Africa  16320539.0     257893.0
#
# [237211 rows x 3 columns]

# %%
new1.groupby('continent').sum()
# Out:
#                  population   total_cases
# continent
# Africa         1.413062e+12  6.375498e+09
# Asia           4.826348e+12  7.148100e+10
# Europe         8.270850e+11  8.363089e+10
# North America  6.194674e+11  5.087865e+10
# Oceania        4.513137e+10  2.816802e+09
# South America  4.383496e+11  3.132925e+10

# %%
#now we can make the chart from that data
